# %%
# !pip install dtale
# Out:
# ...
#   Using cached dtale-2.2.0-py2.py3-none-any.whl (12.7 MB)
# ...
#   Using cached dash_bootstrap_components-1.1.0-py3-none-any.whl (210 kB)
# ...
#   Using cached xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# ...
#   Using cached future-0.18.2.tar.gz (829 kB)
# ...
#   Using cached squarify-0.4.3-py3-none-any.whl (4.3 kB)
# ...
#   Using cached dash_daq-0.5.0.tar.gz (642 kB)
# ...
#   Using cached xarray-2022.3.0-py3-none-any.whl (870 kB)
# ...
#   Using cached missingno-0.4.2-py3-none-any.whl (9.7 kB)
# ...
#   Using cached flask_ngrok-0.0.25-py3-none-any.whl (3.1 kB)
# ...
#   Using cached scikit-learn-0.24.2.tar.gz (7.5 MB)
#   Installing build dependencies: started
#   Installing build dependencies: still running...
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'error'
# ...

# %%
import dtale

# %%
import pandas as pd
import seaborn as sns

# %%
df = sns.load_dataset("titanic")

# %%
dtale.show(df)
# Out:
# 2022-04-25 21:26:20,068 - INFO     - NumExpr defaulting to 4 threads.
#         <iframe
#             width="100%"
#             height="475"
#             src="http://DESKTOP-C1RHBNT:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
